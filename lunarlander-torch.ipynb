# %%
! pip install -r requirements.txt

# %%
import gymnasium as gym
import os 
import matplotlib.pyplot as plt
import json  # for dumping debug data
import time  # for benchmarking
import numpy as np
from ddqn_torch import DoubleQAgent

LEARN_EVERY = 2


def train_agent(n_episodes=2000, load_latest_model=False):
    print(
        "Training a DDQN agent on {} episodes. Pretrained model = {}".format(
            n_episodes, load_latest_model
        )
    )
    env = gym.make("LunarLander-v2")
    agent = DoubleQAgent(
        gamma=0.99,
        epsilon=1.0,
        epsilon_dec=0.995,
        lr=0.001,
        mem_size=200000,
        batch_size=128,
        epsilon_end=0.01,
    )
    if load_latest_model:
        agent.load_saved_model("ddqn_torch_model.h5")
        print("Loaded most recent: ddqn_torch_model.h5")

    scores = []
    eps_history = []
    start = time.time()
    for i in range(n_episodes):
        terminated = False
        truncated = False
        score = 0
        state = env.reset()[0]
        steps = 0
        while not (terminated or truncated):
            action = agent.choose_action(state)
            new_state, reward, terminated, truncated, info = env.step(action)
            agent.save(state, action, reward, new_state, terminated)
            state = new_state
            if steps > 0 and steps % LEARN_EVERY == 0:
                agent.learn()
            steps += 1
            score += reward

        eps_history.append(agent.epsilon)
        scores.append(score)
        avg_score = np.mean(scores[max(0, i - 100) : (i + 1)])

        if (i + 1) % 10 == 0 and i > 0:
            # Report expected time to finish the training
            print(
                "Episode {} in {:.2f} min. Expected total time for {} episodes: {:.0f} min. [{:.2f}/{:.2f}]".format(
                    (i + 1),
                    (time.time() - start) / 60,
                    n_episodes,
                    (((time.time() - start) / i) * n_episodes) / 60,
                    score,
                    avg_score,
                )
            )

        if (i + 1) % 100 == 0 and i > 0:
            # Save the model every 100-th step just in case
            agent.save_model("ddqn_torch_model.h5")
            with open(
                "scores\ddqn_torch_dqn_scores_{}.json".format(int(time.time())), "w"
            ) as fp:
                json.dump(scores, fp)
            with open(
                "episodes\ddqn_torch_eps_history_{}.json".format(int(time.time())), "w"
            ) as fp:
                json.dump(eps_history, fp)

    return agent

# %%
# Uncomment to train
agent = train_agent(n_episodes=1500, load_latest_model=False)
# Out:
# Training a DDQN agent on 1500 episodes. Pretrained model = False
# Episode 10 in 0.05 min. Expected total time for 1500 episodes: 8 min. [-286.65/-193.36]
# Episode 20 in 0.26 min. Expected total time for 1500 episodes: 20 min. [-110.78/-165.80]
# Episode 30 in 0.53 min. Expected total time for 1500 episodes: 27 min. [-42.70/-143.79]
# Episode 40 in 0.93 min. Expected total time for 1500 episodes: 36 min. [-18.58/-113.77]
# Episode 50 in 1.34 min. Expected total time for 1500 episodes: 41 min. [3.81/-93.88]
# Episode 60 in 1.77 min. Expected total time for 1500 episodes: 45 min. [-28.95/-85.80]
# Episode 70 in 2.21 min. Expected total time for 1500 episodes: 48 min. [-40.44/-79.52]
# Episode 80 in 2.67 min. Expected total time for 1500 episodes: 51 min. [12.05/-73.49]
# Episode 90 in 3.09 min. Expected total time for 1500 episodes: 52 min. [-63.52/-71.84]
# Episode 100 in 3.56 min. Expected total time for 1500 episodes: 54 min. [-46.22/-68.39]
# Episode 110 in 4.04 min. Expected total time for 1500 episodes: 56 min. [-46.69/-55.14]
# Episode 120 in 4.45 min. Expected total time for 1500 episodes: 56 min. [19.90/-42.26]
# Episode 130 in 4.90 min. Expected total time for 1500 episodes: 57 min. [-150.02/-35.50]
# Episode 140 in 5.32 min. Expected total time for 1500 episodes: 57 min. [-19.43/-37.74]
# Episode 150 in 5.75 min. Expected total time for 1500 episodes: 58 min. [-70.01/-40.05]
# Episode 160 in 6.19 min. Expected total time for 1500 episodes: 58 min. [-62.57/-40.13]
# Episode 170 in 6.64 min. Expected total time for 1500 episodes: 59 min. [-19.73/-39.37]
# Episode 180 in 7.12 min. Expected total time for 1500 episodes: 60 min. [-24.02/-40.21]
# Episode 190 in 7.61 min. Expected total time for 1500 episodes: 60 min. [-40.98/-38.66]
# Episode 200 in 8.07 min. Expected total time for 1500 episodes: 61 min. [-17.71/-37.35]
# Episode 210 in 8.54 min. Expected total time for 1500 episodes: 61 min. [-21.24/-37.76]
# Episode 220 in 9.01 min. Expected total time for 1500 episodes: 62 min. [-69.80/-36.23]
# Episode 230 in 9.50 min. Expected total time for 1500 episodes: 62 min. [-37.44/-38.86]
# Episode 240 in 9.98 min. Expected total time for 1500 episodes: 63 min. [-50.40/-34.04]
# Episode 250 in 10.47 min. Expected total time for 1500 episodes: 63 min. [-28.72/-35.77]
# Episode 260 in 10.95 min. Expected total time for 1500 episodes: 63 min. [8.99/-33.97]
# Episode 270 in 11.44 min. Expected total time for 1500 episodes: 64 min. [-36.03/-33.52]
# Episode 280 in 11.88 min. Expected total time for 1500 episodes: 64 min. [-27.32/-28.01]
# Episode 290 in 12.08 min. Expected total time for 1500 episodes: 63 min. [208.54/-9.50]
# Episode 300 in 12.24 min. Expected total time for 1500 episodes: 61 min. [234.13/-0.94]
# Episode 310 in 12.44 min. Expected total time for 1500 episodes: 60 min. [253.75/25.61]
# Episode 320 in 12.61 min. Expected total time for 1500 episodes: 59 min. [234.71/43.88]
# Episode 330 in 12.76 min. Expected total time for 1500 episodes: 58 min. [282.55/68.73]
# Episode 340 in 12.86 min. Expected total time for 1500 episodes: 57 min. [255.50/82.27]
# Episode 350 in 12.97 min. Expected total time for 1500 episodes: 56 min. [177.31/99.49]
# Episode 360 in 13.19 min. Expected total time for 1500 episodes: 55 min. [-66.21/100.11]
# Episode 370 in 13.38 min. Expected total time for 1500 episodes: 54 min. [252.77/127.16]
# Episode 380 in 13.54 min. Expected total time for 1500 episodes: 54 min. [21.82/141.54]
# Episode 390 in 13.69 min. Expected total time for 1500 episodes: 53 min. [209.50/149.43]
# Episode 400 in 13.83 min. Expected total time for 1500 episodes: 52 min. [255.35/157.88]
# Episode 410 in 14.05 min. Expected total time for 1500 episodes: 52 min. [247.74/150.77]
# Episode 420 in 14.30 min. Expected total time for 1500 episodes: 51 min. [247.33/154.82]
# Episode 430 in 14.53 min. Expected total time for 1500 episodes: 51 min. [246.44/155.93]
# Episode 440 in 14.73 min. Expected total time for 1500 episodes: 50 min. [242.79/166.37]
# Episode 450 in 14.91 min. Expected total time for 1500 episodes: 50 min. [278.35/176.75]
# Episode 460 in 15.08 min. Expected total time for 1500 episodes: 49 min. [-38.83/191.27]
# Episode 470 in 15.27 min. Expected total time for 1500 episodes: 49 min. [255.78/190.66]
# Episode 480 in 15.45 min. Expected total time for 1500 episodes: 48 min. [263.94/197.69]
# Episode 490 in 15.61 min. Expected total time for 1500 episodes: 48 min. [265.81/202.13]
# Episode 500 in 15.79 min. Expected total time for 1500 episodes: 47 min. [258.50/206.74]
# Episode 510 in 15.95 min. Expected total time for 1500 episodes: 47 min. [-116.41/213.13]
# Episode 520 in 16.17 min. Expected total time for 1500 episodes: 47 min. [257.43/213.97]
# Episode 530 in 16.46 min. Expected total time for 1500 episodes: 47 min. [229.15/210.73]
# Episode 540 in 16.64 min. Expected total time for 1500 episodes: 46 min. [229.41/212.37]
# Episode 550 in 16.83 min. Expected total time for 1500 episodes: 46 min. [242.47/208.25]
# Episode 560 in 17.01 min. Expected total time for 1500 episodes: 46 min. [256.15/210.43]
# Episode 570 in 17.19 min. Expected total time for 1500 episodes: 45 min. [243.48/218.79]
# Episode 580 in 17.33 min. Expected total time for 1500 episodes: 45 min. [286.94/217.84]
# Episode 590 in 17.50 min. Expected total time for 1500 episodes: 45 min. [264.45/220.23]
# Episode 600 in 17.67 min. Expected total time for 1500 episodes: 44 min. [279.16/228.05]
# Episode 610 in 17.82 min. Expected total time for 1500 episodes: 44 min. [258.50/227.71]
# Episode 620 in 17.97 min. Expected total time for 1500 episodes: 44 min. [281.58/234.63]
# Episode 630 in 18.11 min. Expected total time for 1500 episodes: 43 min. [298.27/243.51]
# Episode 640 in 18.26 min. Expected total time for 1500 episodes: 43 min. [285.11/241.46]
# Episode 650 in 18.41 min. Expected total time for 1500 episodes: 43 min. [274.43/249.69]
# Episode 660 in 18.55 min. Expected total time for 1500 episodes: 42 min. [278.69/251.13]
# Episode 670 in 18.68 min. Expected total time for 1500 episodes: 42 min. [219.65/251.23]
# Episode 680 in 18.84 min. Expected total time for 1500 episodes: 42 min. [225.50/248.59]
# Episode 690 in 18.98 min. Expected total time for 1500 episodes: 41 min. [-378.90/242.71]
# Episode 700 in 19.14 min. Expected total time for 1500 episodes: 41 min. [-413.81/225.26]
# Episode 710 in 19.29 min. Expected total time for 1500 episodes: 41 min. [259.56/225.95]
# Episode 720 in 19.43 min. Expected total time for 1500 episodes: 41 min. [264.36/226.50]
# Episode 730 in 19.60 min. Expected total time for 1500 episodes: 40 min. [196.11/224.31]
# Episode 740 in 19.79 min. Expected total time for 1500 episodes: 40 min. [282.85/222.73]
# Episode 750 in 19.93 min. Expected total time for 1500 episodes: 40 min. [198.67/220.95]
# Episode 760 in 20.09 min. Expected total time for 1500 episodes: 40 min. [245.69/222.49]
# Episode 770 in 20.24 min. Expected total time for 1500 episodes: 39 min. [287.39/221.21]
# Episode 780 in 20.45 min. Expected total time for 1500 episodes: 39 min. [251.03/224.55]
# Episode 790 in 20.58 min. Expected total time for 1500 episodes: 39 min. [287.90/221.23]
# Episode 800 in 20.70 min. Expected total time for 1500 episodes: 39 min. [261.00/238.57]
# Episode 810 in 20.87 min. Expected total time for 1500 episodes: 39 min. [275.66/244.75]
# Episode 820 in 20.99 min. Expected total time for 1500 episodes: 38 min. [250.45/245.94]
# Episode 830 in 21.11 min. Expected total time for 1500 episodes: 38 min. [293.22/248.46]
# Episode 840 in 21.24 min. Expected total time for 1500 episodes: 38 min. [268.76/255.26]
# Episode 850 in 21.37 min. Expected total time for 1500 episodes: 38 min. [255.79/256.36]
# Episode 860 in 21.49 min. Expected total time for 1500 episodes: 38 min. [220.75/257.35]
# Episode 870 in 21.61 min. Expected total time for 1500 episodes: 37 min. [282.89/258.48]
# Episode 880 in 21.76 min. Expected total time for 1500 episodes: 37 min. [227.59/261.29]
# Episode 890 in 21.89 min. Expected total time for 1500 episodes: 37 min. [272.87/265.27]
# Episode 900 in 21.99 min. Expected total time for 1500 episodes: 37 min. [241.60/265.48]
# Episode 910 in 22.12 min. Expected total time for 1500 episodes: 37 min. [242.42/267.18]
# Episode 920 in 22.25 min. Expected total time for 1500 episodes: 36 min. [251.68/267.19]
# Episode 930 in 22.36 min. Expected total time for 1500 episodes: 36 min. [263.19/267.22]
# Episode 940 in 22.48 min. Expected total time for 1500 episodes: 36 min. [261.01/266.13]
# Episode 950 in 22.63 min. Expected total time for 1500 episodes: 36 min. [270.19/263.86]
# Episode 960 in 22.76 min. Expected total time for 1500 episodes: 36 min. [-72.86/259.21]
# Episode 970 in 22.87 min. Expected total time for 1500 episodes: 35 min. [-7.28/256.21]
# Episode 980 in 23.03 min. Expected total time for 1500 episodes: 35 min. [258.81/254.26]
# Episode 990 in 23.19 min. Expected total time for 1500 episodes: 35 min. [196.99/240.92]
# Episode 1000 in 23.33 min. Expected total time for 1500 episodes: 35 min. [256.75/231.38]
# Episode 1010 in 23.47 min. Expected total time for 1500 episodes: 35 min. [234.27/231.04]
# Episode 1020 in 23.61 min. Expected total time for 1500 episodes: 35 min. [273.25/225.01]
# Episode 1030 in 23.74 min. Expected total time for 1500 episodes: 35 min. [234.58/226.31]
# Episode 1040 in 23.86 min. Expected total time for 1500 episodes: 34 min. [213.67/223.78]
# Episode 1050 in 23.97 min. Expected total time for 1500 episodes: 34 min. [-30.76/206.21]
# Episode 1060 in 24.09 min. Expected total time for 1500 episodes: 34 min. [253.18/207.57]
# Episode 1070 in 24.20 min. Expected total time for 1500 episodes: 34 min. [266.70/212.89]
# Episode 1080 in 24.33 min. Expected total time for 1500 episodes: 34 min. [208.68/213.63]
# Episode 1090 in 24.45 min. Expected total time for 1500 episodes: 34 min. [283.08/227.21]
# Episode 1100 in 24.57 min. Expected total time for 1500 episodes: 34 min. [240.16/235.59]
# Episode 1110 in 24.73 min. Expected total time for 1500 episodes: 33 min. [225.43/233.42]
# Episode 1120 in 24.86 min. Expected total time for 1500 episodes: 33 min. [208.97/237.83]
# Episode 1130 in 25.00 min. Expected total time for 1500 episodes: 33 min. [268.95/236.51]
# Episode 1140 in 25.13 min. Expected total time for 1500 episodes: 33 min. [278.62/239.81]
# Episode 1150 in 25.24 min. Expected total time for 1500 episodes: 33 min. [273.28/254.20]
# Episode 1160 in 25.37 min. Expected total time for 1500 episodes: 33 min. [312.87/260.40]
# Episode 1170 in 25.50 min. Expected total time for 1500 episodes: 33 min. [265.69/261.25]
# Episode 1180 in 25.62 min. Expected total time for 1500 episodes: 33 min. [259.00/263.88]
# Episode 1190 in 25.76 min. Expected total time for 1500 episodes: 32 min. [260.21/266.27]
# Episode 1200 in 25.87 min. Expected total time for 1500 episodes: 32 min. [301.38/267.11]
# Episode 1210 in 26.00 min. Expected total time for 1500 episodes: 32 min. [300.27/269.50]
# Episode 1220 in 26.12 min. Expected total time for 1500 episodes: 32 min. [299.32/271.77]
# Episode 1230 in 26.27 min. Expected total time for 1500 episodes: 32 min. [290.73/271.92]
# Episode 1240 in 26.39 min. Expected total time for 1500 episodes: 32 min. [251.16/270.99]
# Episode 1250 in 26.52 min. Expected total time for 1500 episodes: 32 min. [266.88/273.67]
# Episode 1260 in 26.63 min. Expected total time for 1500 episodes: 32 min. [247.55/271.82]
# Episode 1270 in 26.76 min. Expected total time for 1500 episodes: 32 min. [302.23/267.79]
# Episode 1280 in 26.88 min. Expected total time for 1500 episodes: 32 min. [270.34/267.73]
# Episode 1290 in 27.02 min. Expected total time for 1500 episodes: 31 min. [295.79/263.18]
# Episode 1300 in 27.14 min. Expected total time for 1500 episodes: 31 min. [282.86/263.07]
# Episode 1310 in 27.30 min. Expected total time for 1500 episodes: 31 min. [235.31/261.44]
# Episode 1320 in 27.41 min. Expected total time for 1500 episodes: 31 min. [232.64/260.46]
# Episode 1330 in 27.58 min. Expected total time for 1500 episodes: 31 min. [274.40/253.42]
# Episode 1340 in 27.73 min. Expected total time for 1500 episodes: 31 min. [233.06/250.93]
# Episode 1350 in 27.85 min. Expected total time for 1500 episodes: 31 min. [-8.16/244.98]
# Episode 1360 in 27.97 min. Expected total time for 1500 episodes: 31 min. [240.07/245.38]
# Episode 1370 in 28.11 min. Expected total time for 1500 episodes: 31 min. [273.61/247.35]
# Episode 1380 in 28.23 min. Expected total time for 1500 episodes: 31 min. [266.00/246.46]
# Episode 1390 in 28.37 min. Expected total time for 1500 episodes: 31 min. [265.43/249.27]
# Episode 1400 in 28.49 min. Expected total time for 1500 episodes: 31 min. [260.76/249.37]
# Episode 1410 in 28.61 min. Expected total time for 1500 episodes: 30 min. [292.90/250.76]
# Episode 1420 in 28.73 min. Expected total time for 1500 episodes: 30 min. [272.60/251.27]
# Episode 1430 in 28.86 min. Expected total time for 1500 episodes: 30 min. [257.54/258.36]
# Episode 1440 in 28.99 min. Expected total time for 1500 episodes: 30 min. [289.00/261.68]
# Episode 1450 in 29.11 min. Expected total time for 1500 episodes: 30 min. [223.06/264.42]
# Episode 1460 in 29.24 min. Expected total time for 1500 episodes: 30 min. [291.18/267.92]
# Episode 1470 in 29.39 min. Expected total time for 1500 episodes: 30 min. [257.93/267.07]
# Episode 1480 in 29.50 min. Expected total time for 1500 episodes: 30 min. [258.42/258.09]
# Episode 1490 in 29.65 min. Expected total time for 1500 episodes: 30 min. [212.36/254.01]
# Episode 1500 in 29.76 min. Expected total time for 1500 episodes: 30 min. [293.73/254.47]

# %%
# Visualize the model
import gymnasium as gym
import os
import matplotlib.pyplot as plt

os.environ["SDL_VIDEODRIVER"] = "dummy"
from IPython.display import clear_output

# Set path to the model to visualize
model_to_animate = "ddqn_torch_model.h5"


def animate_model(name, atype="single"):
    env = gym.make("LunarLander-v2", render_mode="rgb_array")
    agent = DoubleQAgent(
        gamma=0.99,
        epsilon=0.0,
        lr=0.0005,
        mem_size=200000,
        batch_size=64,
        epsilon_end=0.01,
    )
    agent.load_saved_model(name)
    state, info = env.reset(seed=12)
    for _ in range(5):
        terminated = False
        truncated = False
        while not (terminated or truncated):
            action = agent.choose_action(state)
            new_state, reward, terminated, truncated, info = env.step(action)
            state = new_state
            clear_output(wait=True)
            plt.imshow(env.render())
            plt.show()
        state = env.reset()[0]
    env.close()


animate_model(model_to_animate, atype="double")
